# %% [markdown]
# # 4. Übung DIS 1.1
#
# Wie immer... Bitte bearbeiten Sie die nachfolgenden Aufgaben, um Ihre Programmierfähigkeiten zu festigen!
# Es geht um Wiederholungen, eigene Funktionen, um Alternativen und Schleifen.

# %% [markdown]
# ## 4.1 Zahlen ausgeben
# 1. Übersetze in einer Funktion (mit if-elif-else) die Zahlen 0 bis 9 in Text. `digit2str(digit)`
# 2. Suche 2 verschiedene Alternativen für die Umsetzung und prüfe `match`. Hinweis: Man kann if-else Konstruktionen auch ineinander verschachteln.
# 3. Überlege und begründe, was wäre die "beste", d.h. schnellste Lösung?

# %% [markdown]
# ## 4.2 Countdown
#
# 1. Gib alle Zahlen von 10 aus abwärts aus
# 2. Zähle langsam herunter
#
# TIPP:
# ````
# # Ganz zu Beginn einfügen...
# from time import sleep # Bibliothek verwenden
# ....
# sleep(1) # Wartet 1 Sekunde
# ````

# %% [markdown]
# ## 4.3 Schleifen, Schleifen, Schleifen
# 1. Schreibe eine Funktion `printKurstabelle(Waehrung, KursZuEUR)` und erzeuge eine Umrechnungstabelle mit den folgenden 4 Spalten und 100 Zeilen:
# ````
# Kurs: 1.05
# EUR   Währung  Währung EUR
# 1     1.05      1       0.9523
# usw.
# ````
# 2. Finde alle [Pythagoreischen-Zahlentripel](https://de.wikipedia.org/wiki/Pythagoreisches_Tripel) bis zu einer vorgebenen Größe (z.B. 100) mit einem [Brute-Force-Ansatz](https://de.wikipedia.org/wiki/Brute-Force-Methode). Verwende drei ineinandergeschaltelte Schleifen.
# 3. Finde eine bessere, d.h. schnellere Lösung.
# 4. Schreibe eine Funktion `isHappyNumber(z)`, die zu einer angegebenen Zahl `z` ermittelt, ob diese "fröhlich" ist. Schau nach, was eine [Fröhliche Zahl](https://de.wikipedia.org/wiki/Fr%C3%B6hliche_Zahl) ist und schreibe eine entsprechende Funktion.
#
#     Tipps:
#     * Es handelt sich nicht um eine Schleife, die zählt, sondern es gibt eine andere Abbruchbedingung.
#     * Die Extraktion der einzelnen Ziffern erfolgt über `%10` und die Berechnung findet einer Schleife statt.
#     * Gib evtl. einzelte Berechnungsschritte zwischendurch mit `print()` aus, um es besser zu verstehen.
# 5. Berechne mit einem Brute-Force-Ansatz und drei ineinander geschachtelter Schleifen alle dreistelligen [narzistischen Zahlen](https://de.wikipedia.org/wiki/Narzisstische_Zahl).

# %% [markdown]
# ## 4.4 Schleifen mit ASCII-Art üben
# 1. Male ein Dreieck mit `groesse` (hier 3) mit der Spitze nach unten. Schaue genau auf die Anzahl der * und Leerzeichen.
# ````
# ******
# ****
# **
# ````
# 2. Male ein Parallelogramm mit einer Höhe von h und einer Breite b (Beispiel h=3,b=6)
# ````
#   ******
#  ******
# ******
# ````

# %% [markdown]
# ## 4.5 Primzahlen
#
# 1. Schreibe eine Funktion `printPrimfaktorzerlegung(z)`, die die Zerlegung von `z` in Primfaktoren ausgibt.
# ````
# printPrimfaktorzerlegung(12)
#
# 2 * 2 * 3
#
# printPrimfaktorzerlegung(7)
#
# 7
#
# printPrimfaktorzerlegung(30)
#
# 2 * 3 * 5
#
# ````
#
# 2. Schreibe eine Funktion `isPrimzahl(z)`, die zu einer angegebenen natürlichen Zahl deren Primeigenschaft ermittelt.Wenn `z` eine Primzahl ist, verwende `return True` ansonsten `return False`.
#
# Tipps:
# 1. `z` ist immer eine natürliche Zahl
# 2. Verstehen... Was ist eine Primzahl, woran erkennt man diese, usw..
# 3. Primfaktorzerlegung: Ermitteln Sie alle Faktoren von klein nach groß
