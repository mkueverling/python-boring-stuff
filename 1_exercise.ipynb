# %% [markdown]
# # 1. Übung DIS 1.1
# ## Speichern und Laden von Dateien
# Einfaches Beispielprogramm schreiben und wieder laden
# * Geben Sie Ihren eigenen Namen mittel `print()` aus!
# * Speichern Sie das Programm unter einem sinnvollen Namen ab
# * Rechner ausschalten (oder Python schließen).
# * Danach laden Sie das Programm wieder und geben Sie Ihren Namen mit dem berechtigten Zusatz *ist einfach toll* aus.

# %% [markdown]
# ## Ermitteln Sie die Ergebnisse mit `print()`
# * 5 + 10
# * 3 * 7
# * (17 - 2) * 8
# * 2^16^ (2 hoch 16)
# * 37 / 3
# * 37 / 3 (Nur ganzzahliger Teil = 12)
# * Rest der Division 37 / 3
# * 12 + 3*3/4 - 3 - 2

# %%
print(5+10)

# %% [markdown]
# ## Markdown
# Schreiben Sie einen kurzen Text zum Unterschied zwischen Markdown und HTML in Markdown. Nutzen Sie hierbei möglichst viele Elemente von Markdown.
# (Überschriften, Fett, Kursiv, Aufzählungen, Link usw.)

# %% [markdown]
# ## Treibstoffverbrauch
# Sie sind 60 km gefahren und mussten 2,6 Liter Diesel tanken. Ein Liter Diesel kostet 1,64.
#
# 1. Definieren Sie für diese Werte drei Variablen
# 2. Berechne in einer zusätzlichen Variable den Verbrauch in l pro 100 km und gib den Wert aus.
# 3. Berechne in einer zusätzlichen Variable die Kosten pro km und gib den Wert aus.

# %%
km = 60

# %% [markdown]
# ## Quadratische Gleichung
# 1. Suche die Lösung für eine quadratische Gleichung der Form x²+px+q=0
# 2. Verwende gültige Werte wie p=5 und q=-8,
# 2. Schreibe ein Programm zur Lösung der Gleichung.
#
# Tipp: Sie kommen ohne math.sqrt(...) aus! `**` ist der Potenzoperator

# %%
# Lösungen einer quadratischen Gleichung mit der p/q-Formel 
p = 5
